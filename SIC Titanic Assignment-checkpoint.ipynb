# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/shashank/Codebase/SIC'

# %%
df=pd.read_csv(r"./titanic_train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
plt.figure(figsize=(15,12))
sns.set_style(style='whitegrid')
plt.subplot(3,3,1)
sns.boxplot(y='PassengerId',data=df)
plt.subplot(3,3,2)
sns.boxplot(y='Survived',data=df)
plt.subplot(3,3,3)
sns.boxplot(y='Pclass',data=df)
plt.subplot(3,3,4)
sns.boxplot(y='Age',data=df)
plt.subplot(3,3,5)
sns.boxplot(y='SibSp',data=df)
plt.subplot(3,3,6)
sns.boxplot(y=	'Parch',data=df)
plt.subplot(3,3,7)
sns.boxplot(y='Fare',data=df)
# Out:
# <Axes: ylabel='Fare'>

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_duplicate=df[df.duplicated()]

# %%
df_duplicate
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df[df['PassengerId']==0].shape[0])
# Out:
# 0

# %%
print(df[df['Survived']==0].shape[0])
# Out:
# 549

# %%
print(df[df['Pclass']==0].shape[0])
# Out:
# 0

# %%
print(df[df['SibSp']==0].shape[0])
# Out:
# 608

# %%
print(df[df['Parch']==0].shape[0])
# Out:
# 678

# %%
df['PassengerId'].hist()
# Out:
# <Axes: >

# %%
df['Survived'].hist()
# Out:
# <Axes: >

# %%
df['Pclass'].hist()
# Out:
# <Axes: >

# %%
df['SibSp'].hist()
# Out:
# <Axes: >

# %%
df['Parch'].hist()
# Out:
# <Axes: >

# %%
df['PassengerId']=df['PassengerId'].replace(0,df['PassengerId'].mean())

# %%
df['Survived']=df['Survived'].replace(0,df['Survived'].median())

# %%
df['Pclass']=df['Pclass'].replace(0,df['Pclass'].median())

# %%
df['SibSp']=df['SibSp'].replace(0,df['SibSp'].median())

# %%
df['Parch']=df['Parch'].replace(0,df['Parch'].median())

# %%
print(df[df['PassengerId']==0].shape[0])
print(df[df['Survived']==0].shape[0])
print(df[df['Pclass']==0].shape[0])
print(df[df['SibSp']==0].shape[0])
print(df[df['Parch']==0].shape[0])
# Out:
# 0
# 549
# 0
# 608
# 678

# %%
plt.figure(figsize=(15,12))
sns.set_style(style='whitegrid')
plt.subplot(3,3,1)
sns.boxplot(y='PassengerId',data=df)
plt.subplot(3,3,2)
sns.boxplot(y='Survived',data=df)
plt.subplot(3,3,3)
sns.boxplot(y='Pclass',data=df)
plt.subplot(3,3,4)
sns.boxplot(y='Age',data=df)
plt.subplot(3,3,5)
sns.boxplot(y='SibSp',data=df)
plt.subplot(3,3,6)
sns.boxplot(y='Parch',data=df)
plt.subplot(3,3,7)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
Q1=df.quantile(0.25)
Q2=df.quantile(0.50)
Q3=df.quantile(0.75)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 Q1=df.quantile(0.25)
#       2 Q2=df.quantile(0.50)
#       3 Q3=df.quantile(0.75)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:11786, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   11779 axis = self._get_axis_number(axis)
#   11781 if not is_list_like(q):
#   11782     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   11783     # error: List item 0 has incompatible type "Union[float, Union[Union[
#   11784     # ExtensionArray, ndarray[Any, Any]], Index, Series], Sequence[float]]";
#   11785     # expected "float"
# > 11786     res_df = self.quantile(  # type: ignore[call-overload]
#   11787         [q],
#   11788         axis=axis,
#   11789         numeric_only=numeric_only,
# ...

# %%
IQR=Q3-Q1
IQR
# Out:
# PassengerId    445.0000
# Survived         1.0000
# Pclass           1.0000
# Age             17.8750
# SibSp            1.0000
# Parch            0.0000
# Fare            23.0896
# dtype: float64

# %%
Lower_Limit=Q1-(1.5*IQR)
Lower_Limit
# Out:
# PassengerId   -444.0000
# Survived        -1.5000
# Pclass           0.5000
# Age             -6.6875
# SibSp           -1.5000
# Parch            0.0000
# Fare           -26.7240
# dtype: float64

# %%
Upper_Limit=Q3+(1.5*IQR)
Upper_Limit
# Out:
# PassengerId    1336.0000
# Survived          2.5000
# Pclass            4.5000
# Age              64.8125
# SibSp             2.5000
# Parch             0.0000
# Fare             65.6344
# dtype: float64

# %%
df1=df[(df>Lower_Limit)&(df<Upper_Limit)]
df1
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch    Fare
# 0              1         0       3  22.0    1.0    NaN   7.250
# 1              2         1       1  38.0    1.0    NaN     NaN
# 2              3         1       3  26.0    0.0    NaN   7.925
# 3              4         1       1  35.0    1.0    NaN  53.100
# 4              5         0       3  35.0    0.0    NaN   8.050
# ..           ...       ...     ...   ...    ...    ...     ...
# 886          887         0       2  27.0    0.0    NaN  13.000
# 887          888         1       1  19.0    0.0    NaN  30.000
# 888          889         0       3   NaN    1.0    NaN  23.450
# 889          890         1       1  26.0    0.0    NaN  30.000
# 890          891         0       3  32.0    0.0    NaN   7.750
#
# [891 rows x 7 columns]

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  Parch  \
# count   891.000000  891.000000  891.000000  703.000000  845.000000    0.0
# mean    446.000000    0.383838    2.308642   29.072077    0.313609    NaN
# std     257.353842    0.486592    0.836071   13.728478    0.530909    NaN
# min       1.000000    0.000000    1.000000    0.420000    0.000000    NaN
# 25%     223.500000    0.000000    2.000000   20.000000    0.000000    NaN
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    NaN
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    NaN
# max     891.000000    1.000000    3.000000   64.000000    2.000000    NaN
#
#              Fare
# count  775.000000
# mean    17.822091
# std     13.578085
# min      0.000000
# 25%      7.895800
# 50%     13.000000
# 75%     26.000000
# max     65.000000

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            188
# SibSp            0
# Parch            0
# Fare           116
# dtype: int64

# %%
df1.hist(bins=10,figsize=(10,10))
plt.show()

# %%
df1['PassengerId']=df['PassengerId'].fillna(df['PassengerId'].mean())
df1['Survived']=df['Survived'].fillna(df['Survived'].median())
df1['Pclass']=df['Pclass'].fillna(df['Pclass'].median())
df1['SibSp']=df['SibSp'].fillna(df['SibSp'].median())
df1['Parch']=df['Parch'].fillna(df['Parch'].median())

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            188
# SibSp            0
# Parch            0
# Fare           116
# dtype: int64

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  703.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.072077    0.523008
# std     257.353842    0.486592    0.836071   13.728478    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   64.000000    8.000000
#
#             Parch        Fare
# count  891.000000  775.000000
# mean     0.381594   17.822091
# std      0.806057   13.578085
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   13.000000
# 75%      0.000000   26.000000
# max      6.000000   65.000000

# %%
sns.countplot(x='Fare',data=df1)
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
X=df1.drop(['Fare'],axis=1)
Y=df1['Fare']

# %%
X.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch
# count   891.000000  891.000000  891.000000  703.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.072077    0.523008    0.381594
# std     257.353842    0.486592    0.836071   13.728478    1.102743    0.806057
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.000000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    1.000000    3.000000   64.000000    8.000000    6.000000

# %%
Y.describe()
# Out:
# count    775.000000
# mean      17.822091
# std       13.578085
# min        0.000000
# 25%        7.895800
# 50%       13.000000
# 75%       26.000000
# max       65.000000
# Name: Fare, dtype: float64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Age          703 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 41.9 KB

# %%
Y.shape
# Out:
# (891,)

# %%
Y.isnull().sum()
# Out:
# 116

# %%
X.shape
# Out:
# (891, 6)

# %%
Y.shape
# Out:
# (891,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=51,stratify=Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=51,stratify=Y)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:2583, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2579         CVClass = ShuffleSplit
#    2581     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
# -> 2583     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2585 return list(
#    2586     chain.from_iterable(
#    2587         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2588     )
#    2589 )
#
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
best_accuracy=[]

for k in range(1,10):
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,Y_train)
    Y_pred=knn.predict(X_test)
    accuracy=accuracy_score(Y_test,Y_pred)
    best_accuracy.append(accuracy)
    
plt.figure(figsize=(12,18))
plt.plot(range(1,10),best_accuracy,markersize=10)
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('accuracy')
plt.title('KNN Accuracy for Different k Values')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 5
#       3 for k in range(1,10):
#       4     knn=KNeighborsClassifier(n_neighbors=k)
# ----> 5     knn.fit(X_train,Y_train)
#       6     Y_pred=knn.predict(X_test)
#       7     accuracy=accuracy_score(Y_test,Y_pred)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_classification.py:215, in KNeighborsClassifier.fit(self, X, y)
#     196 """Fit the k-nearest neighbors classifier from the training dataset.
#     197
#     198 Parameters
#    (...)
#     211     The fitted k-nearest neighbors classifier.
#     212 """
#     213 self._validate_params()
# --> 215 return self._fit(X, y)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_base.py:454, in NeighborsBase._fit(self, X, y)
#     452 if self._get_tags()["requires_y"]:
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=10)

# %%
knn.fit(X_train,Y_train)
