stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.isalnum() and word not in stop_words]

# Sentiment Analysis
sia = SentimentIntensityAnalyzer()
sentiment_scores = sia.polarity_scores(speech)

print("Sentiment Analysis Results:")
print(f"Positive: {sentiment_scores['pos']:.2f}")
print(f"Neutral: {sentiment_scores['neu']:.2f}")
print(f"Negative: {sentiment_scores['neg']:.2f}")
print(f"Compound: {sentiment_scores['compound']:.2f}")

# Interpreting the sentiment
if sentiment_scores['compound'] >= 0.05:
    print("The overall sentiment of the speech is positive.")
elif sentiment_scores['compound'] <= -0.05:
    print("The overall sentiment of the speech is negative.")
else:
    print("The overall sentiment of the speech is neutral.")

# Generate Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(filtered_tokens))

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of the Speech')
plt.show()

# Frequency Distribution
freq_dist = nltk.FreqDist(filtered_tokens)
top_words = freq_dist.most_common(10)

# Create a bar plot of top words
plt.figure(figsize=(10, 5))
sns.barplot(x=[word[0] for word in top_words], y=[word[1] for word in top_words])
plt.title('Top 10 Most Frequent Words')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# Sentiment Distribution
sentences = nltk.sent_tokenize(speech)
sentence_sentiments = [sia.polarity_scores(sentence)['compound'] for sentence in sentences]

plt.figure(figsize=(10, 5))
sns.histplot(sentence_sentiments, kde=True)
plt.title('Distribution of Sentiment Scores Across Sentences')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.show()

# Topic Analysis (simplified version)
topics = ['climate', 'energy', 'india', 'global', 'green']
topic_counts = {topic: sum(1 for token in filtered_tokens if topic in token) for topic in topics}

plt.figure(figsize=(10, 5))
sns.barplot(x=list(topic_counts.keys()), y=list(topic_counts.values()))
plt.title('Frequency of Key Topics')
plt.xlabel('Topics')
plt.ylabel('Frequency')
plt.show()

# Sentiment over time (assuming each sentence represents a time point)
plt.figure(figsize=(12, 6))
plt.plot(range(len(sentence_sentiments)), sentence_sentiments, marker='o')
plt.title('Sentiment Progression Throughout the Speech')
plt.xlabel('Sentence Number')
plt.ylabel('Sentiment Score')
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

print("\nProject Conclusion:")
print("This analysis provides insights into the sentiment, key topics, and language patterns of the given speech.")
print("The overall sentiment appears to be positive, with a focus on global cooperation, environmental initiatives, and India's role in various sectors.")
print("The word cloud and frequency distributions highlight the most prominent themes and words used in the speech.")
print("The sentiment progression graph shows how the emotional tone varied throughout the speech, which could be useful for understanding its structure and impact.")
print("This project demonstrates the power of natural language processing and data visualization in extracting meaningful insights from textual data.")
# Out:
# [nltk_data] Downloading package punkt to /Users/shashank/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shashank/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/shashank/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Sentiment Analysis Results:
# Positive: 0.22
# Neutral: 0.77
# Negative: 0.01
# Compound: 1.00
# The overall sentiment of the speech is positive.
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# Project Conclusion:
# This analysis provides insights into the sentiment, key topics, and language patterns of the given speech.
# The overall sentiment appears to be positive, with a focus on global cooperation, environmental initiatives, and India's role in various sectors.
# The word cloud and frequency distributions highlight the most prominent themes and words used in the speech.
# The sentiment progression graph shows how the emotional tone varied throughout the speech, which could be useful for understanding its structure and impact.
# This project demonstrates the power of natural language processing and data visualization in extracting meaningful insights from textual data.
